# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movie_data=pd.read_csv("IMDB-Movie-Data.csv")

# %% [markdown]
# First, I took a quick glance on my data in search of missing values or absurd values. I found that there are a total of 192 cells with no value.I foumd that a lot of movies from 2016 have 0 as their value in the revenue column. At first, I thought it was missing data, but then saw that mydataset only encompasses movie data up to 2016 and perhaps was left uncomplete.
#
# I think that moving forward we can:
#
#     a) delete the rows with empty values and focus on the 2016 movies with values
#     b) delte the rows and not include 2016 in our hypothesis question
#     c) update the informations ourselves from another data set.
#
# Note: there are a couple of movies not from 2016 whom also have no value in the revenue column. For our purposes, I will delete all empty cells in the dataset because we have plenty of other movies for every year to make conclusions.

# %%
print(movie_data.isnull().sum(axis=0))
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
movie_data_2016=movie_data[movie_data.Year == 2016]

# %%
movie_data_2016
# Out:
#      Rank                                          Title  \
# 2       3                                          Split
# 3       4                                           Sing
# 4       5                                  Suicide Squad
# 5       6                                 The Great Wall
# 6       7                                     La La Land
# 7       8                                       Mindhorn
# 8       9                             The Lost City of Z
# 9      10                                     Passengers
# 10     11        Fantastic Beasts and Where to Find Them
# 11     12                                 Hidden Figures
# 12     13                                      Rogue One
# 13     14                                          Moana
# 14     15                                       Colossal
# 15     16                        The Secret Life of Pets
# 16     17                                  Hacksaw Ridge
# ...

# %%
print(movie_data_2016.isnull().sum(axis=0))
# Out:
# Rank                   0
# Title                  0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)    92
# Metascore             29
# dtype: int64

# %%
print(movie_data.isnull().sum(axis=0))
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
movie_data_2015=movie_data[movie_data.Year == 2015]
movie_data_2014=movie_data[movie_data.Year == 2014]
movie_data_2013=movie_data[movie_data.Year == 2013]
movie_data_2012=movie_data[movie_data.Year == 2012]
movie_data_2011=movie_data[movie_data.Year == 2011]
movie_data_2010=movie_data[movie_data.Year == 2010]
movie_data_2009=movie_data[movie_data.Year == 2009]
movie_data_2008=movie_data[movie_data.Year == 2008]
movie_data_2007=movie_data[movie_data.Year == 2007]
movie_data_2006=movie_data[movie_data.Year == 2006]

print(movie_data_2015.isnull().sum(axis=0))
print(movie_data_2014.isnull().sum(axis=0))
print(movie_data_2013.isnull().sum(axis=0))
print(movie_data_2012.isnull().sum(axis=0))
print(movie_data_2011.isnull().sum(axis=0))
print(movie_data_2010.isnull().sum(axis=0))
print(movie_data_2009.isnull().sum(axis=0))
print(movie_data_2008.isnull().sum(axis=0))
print(movie_data_2007.isnull().sum(axis=0))
print(movie_data_2006.isnull().sum(axis=0))
# Out:
# Rank                   0
# Title                  0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)    14
# Metascore              4
# dtype: int64
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    4
# Metascore             3
# dtype: int64
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    3
# Metascore             5
# dtype: int64
# ...

# %%
movie_data=movie_data.dropna(axis=0, how='any')
movie_data
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# 17     18                             Jason Bourne
# ...

# %% [markdown]
# I have now deleted all empty cells in my data set. It seems that we still have enough movie data for each year to make conclusions.

# %%
movie_data.
# Out:
#   File "<ipython-input-25-6bfbb8fd5753>", line 1
#     movie_data.
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# I found an entry with a 0 value in the revenue column for a movie released in 2016. I have two explanations for that. One, the movie made less than a million in revenue. Or, the individuals meant to leave that cell as an empty value.
#
#
#
# I also noticed that I can't call specific columns of my data set. I can't call the revenue colum  or the runtime column. This will be problematic moving forward.

# %%
movie_data.Genre.describe()
# Out:
# count                         838
# unique                        189
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: Genre, dtype: object

# %%
(min(movie_data.Genre))
# Out:
# 'Action'

# %%
(movie_data.Genre=="Action").sum()
# Out:
# 1

# %% [markdown]
# Last meeting, we discusses how we should consider grouping the genres of the movies because we have the issue that several movies have mulitple listed genres. I think that this might be a tedious task. I found that of the 838 genre rows, only 189 rows are different from the remaining 649. The remaing 649 rows have other rows with one or more identical cells. The genre with the most and least are listed above. An idea I have is that perhaps we focus on the more popular grouping of genres.

# %%
movie_data=movie_data.drop(columns="Rank")

# %%
movie_data
# Out:
#                                        Title                       Genre  \
# 0                    Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1                                 Prometheus    Adventure,Mystery,Sci-Fi
# 2                                      Split             Horror,Thriller
# 3                                       Sing     Animation,Comedy,Family
# 4                              Suicide Squad    Action,Adventure,Fantasy
# 5                             The Great Wall    Action,Adventure,Fantasy
# 6                                 La La Land          Comedy,Drama,Music
# 8                         The Lost City of Z  Action,Adventure,Biography
# 9                                 Passengers     Adventure,Drama,Romance
# 10   Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# 11                            Hidden Figures     Biography,Drama,History
# 12                                 Rogue One     Action,Adventure,Sci-Fi
# ...

# %% [markdown]
# I decided to drop the "Rank" column because I believe we discussed how it was overlygenerous to some movie. I think that the rank column is biased. We do not know what could have moved the creators of the data set to rank the movies the way they did. Perhaps they were ranked based on how they believe they should be ranked or perhaps used a correlation with a variable they thought to be indicative of ranking to them.

# %%
movie_data= movie_data.sort_values('Year',ascending=False)

# %%
movie_data
# Out:
#                                            Title                       Genre  \
# 999                                   Nine Lives       Comedy,Family,Fantasy
# 166                             Now You See Me 2     Action,Adventure,Comedy
# 204                                    Allegiant    Action,Adventure,Mystery
# 447                    Hunt for the Wilderpeople      Adventure,Comedy,Drama
# 171                     Kubo and the Two Strings  Animation,Adventure,Family
# 611                                 Toni Erdmann                Comedy,Drama
# 178                              The Conjuring 2     Horror,Mystery,Thriller
# 431                                  Zoolander 2                      Comedy
# 808                             A United Kingdom     Biography,Drama,Romance
# 424                            London Has Fallen          Action,Crime,Drama
# 180                         Bridget Jones's Baby              Comedy,Romance
# ...

# %% [markdown]
# I sorted my data set based on the year column. 2016 movies will appear first. I think this will help reading and finding data.

# %%
desc= movie_data.describe()
desc
# Out:
#              Year  Runtime (Minutes)      Rating         Votes  \
# count   838.00000         838.000000  838.000000  8.380000e+02
# mean   2012.50716         114.638425    6.814320  1.932303e+05
# std       3.17236          18.470922    0.877754  1.930990e+05
# min    2006.00000          66.000000    1.900000  1.780000e+02
# 25%    2010.00000         101.000000    6.300000  6.127650e+04
# 50%    2013.00000         112.000000    6.900000  1.368795e+05
# 75%    2015.00000         124.000000    7.500000  2.710830e+05
# max    2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# 75%            116.800000   72.000000
# max            936.630000  100.000000

# %%
plt.hist(x=movie_data['Year'], bins =20)
plt.xlim(2006,2016)
plt.xlabel('year')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.hist(x=movie_data['Revenue (Millions)'], bins=50)
plt.xlabel('Revenue in millions')
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
plt.scatter(x=movie_data['Revenue (Millions)'], y=movie_data['Runtime (Minutes)'], s=30)
plt.xlabel('Revenue in millions')
plt.ylabel("Runtime")
# Out:
# Text(0, 0.5, 'Runtime')

# %%
corr=movie_data.corr()
corr
# Out:
#                         Year  Runtime (Minutes)    Rating     Votes  \
# Year                1.000000          -0.101933 -0.145703 -0.362445
# Runtime (Minutes)  -0.101933           1.000000  0.374566  0.399298
# Rating             -0.145703           0.374566  1.000000  0.517452
# Votes              -0.362445           0.399298  0.517452  1.000000
# Revenue (Millions) -0.129198           0.281721  0.217106  0.636833
# Metascore          -0.062303           0.221397  0.672731  0.332674
#
#                     Revenue (Millions)  Metascore
# Year                         -0.129198  -0.062303
# Runtime (Minutes)             0.281721   0.221397
# Rating                        0.217106   0.672731
# Votes                         0.636833   0.332674
# Revenue (Millions)            1.000000   0.142397
# Metascore                     0.142397   1.000000

# %%
plt.scatter(x=movie_data['Revenue (Millions)'], y=movie_data['Votes'], s=30)
plt.xlabel('Revenue in millions')
plt.ylabel("Votes")
# Out:
# Text(0, 0.5, 'Votes')

# %%
plt.scatter(x=movie_data["Rating"], y=movie_data['Metascore'], s=30)
plt.xlabel('Rating')
plt.ylabel("Metascores")
# Out:
# Text(0, 0.5, 'Metascores')

# %% [markdown]
# I used my scatter plots to find outlier in my data. The highest value in revenue, I thought, could have been an outlier but after matching the value with the movie title it is ver unlikely. The title for that was Star Wars: 'Episode VII - The Force Awakens'.
